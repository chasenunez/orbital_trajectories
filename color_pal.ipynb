# %%
# %pip install colorist
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import math
from colorist import hex

colors = [
    "#f38b8a", "#ffd393", "#cb2855", "#c4bd6c", "#d73423",
    "#706353", "#1f8a70", "#979330", "#e19222", "#979330",
    "#979330", "#979330", "#aec7b2", "#e6dfcf", "#e6dfcf",
    "#e6dfcf", "#e6dfcf", "#e6dfcf", "#e6dfcf", "#e6dfcf",
    "#e6dfcf", "#b6a965", "#d05227", "#7EBCE5", "#cb2655",
    "#e1d9c4", "#A73E5C", "#F34E52", "#738cc1"
]

labels = [
    "MBA", "TJN", "OMB", "GRK", "CEN",
    "MCA", "AST", "TNO", "AMO", "IMB",
    "APO", "ATE", "IEO", "HYA", "PAR",
    "JFc", "COM", "HYP", "HTC", "Etc",
    "JFC", "CTc", "Mercury", "Venus", "Earth",
    "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"
]

for i in range(1, len(colors)):
    hex(labels[i], colors[i])
    #print(f"{colors.}{labels.i}")
# Out:
# TJN
# OMB
# GRK
# CEN
# MCA
# AST
# TNO
# AMO
# IMB
# APO
# ATE
# IEO
# HYA
# PAR
# JFc
# COM
# HYP
# HTC
# Etc
# JFC
# CTc
# Mercury
# Venus
# Earth
# Mars
# Jupiter
# Saturn
# Uranus
